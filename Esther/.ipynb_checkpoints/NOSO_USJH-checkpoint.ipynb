# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("USJH_order_dataset.csv")
# Out:
# /Users/hee-wonchang/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (18,29,30,34,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns = df.columns.str.replace(" ","_")
df.columns
# Out:
# Index(['Name', 'Financial_Status', 'Paid_at', 'Fulfillment_Status',
#        'Accepts_Marketing', 'Currency', 'Subtotal', 'Shipping', 'Taxes',
#        'Total', 'Discount_Code', 'Discount_Amount', 'Shipping_Method',
#        'Created_at', 'Lineitem_quantity', 'Lineitem_name', 'Lineitem_price',
#        'Lineitem_compare_at_price', 'Lineitem_sku',
#        'Lineitem_fulfillment_status', 'Shipping_Street', 'Shipping_Address1',
#        'Shipping_Address2', 'Shipping_Company', 'Shipping_City',
#        'Shipping_Zip', 'Shipping_Province', 'Shipping_Country', 'Notes',
#        'Note_Attributes', 'Cancelled_at', 'Payment_Method', 'Refunded_Amount',
#        'Vendor', 'Tags', 'Risk_Level', 'Source', 'Lineitem_name.1', 'Color_',
#        'Unnamed:_39', 'Unnamed:_40', 'Tax_3_Name'],
#       dtype='object')

# %%
df.head()
# Out:
#     Name Financial_Status        Paid_at Fulfillment_Status Accepts_Marketing  \
# 0  #4746             paid  7/16/18 12:31        unfulfilled               yes
# 1  #4746              NaN            NaN                NaN               NaN
# 2  #4746              NaN            NaN                NaN               NaN
# 3  #4746              NaN            NaN                NaN               NaN
# 4  #4746              NaN            NaN                NaN               NaN
#
#   Currency  Subtotal  Shipping  Taxes   Total    ...     Refunded_Amount  \
# 0      USD     100.5     13.64    0.0  114.14    ...                 0.0
# 1      NaN       NaN       NaN    NaN     NaN    ...                 NaN
# 2      NaN       NaN       NaN    NaN     NaN    ...                 NaN
# 3      NaN       NaN       NaN    NaN     NaN    ...                 NaN
# 4      NaN       NaN       NaN    NaN     NaN    ...                 NaN
#
#              Vendor Tags Risk_Level  Source  \
# 0  US Jewelry House  NaN        Low     web
# 1  US Jewelry House  NaN        NaN     NaN
# 2        impression  NaN        NaN     NaN
# 3              Ella  NaN        NaN     NaN
# 4           Stylist  NaN        NaN     NaN
#
#                                      Lineitem_name.1        Color_  \
# 0                 Turquoise Crystal Rhinestone Ring           GDTQ
# 1                 Turquoise Crystal Rhinestone Ring           GDTQ
# 2  Tri Tone Cubic Zirconia Paved Simple Band Ring...        Size 8
# 3             Geometric Tortoise Link Long Necklace          Brown
# 4  Acetate Skinny Bangle Bracelet With Front Clos...   White/Brown
#
#    Unnamed:_39 Unnamed:_40 Tax_3_Name
# 0          NaN         NaN        NaN
# 1          NaN         NaN        NaN
# 2          NaN         NaN        NaN
# 3          NaN         NaN        NaN
# 4          NaN         NaN        NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ### Columns where NA's can be filled in from the line above (eg, same order ID)

# %%
fill_na_above = ['Financial_Status', 'Paid_at', 'Fulfillment_Status',
       'Accepts_Marketing', 'Currency', 'Subtotal', 'Shipping', 'Taxes',
       'Total', 'Shipping_Method', 'Shipping_Street', 'Shipping_Address1',
       'Shipping_Address2', 'Shipping_Company', 'Shipping_City',
       'Shipping_Zip', 'Shipping_Province', 'Shipping_Country',
       'Payment_Method','Risk_Level', 'Source']

drop = []

# %%
df.loc[:,fill_na_above] = df.loc[:,fill_na_above].fillna(method='ffill')
df.head()
# Out:
#     Name Financial_Status        Paid_at Fulfillment_Status Accepts_Marketing  \
# 0  #4746             paid  7/16/18 12:31        unfulfilled               yes
# 1  #4746             paid  7/16/18 12:31        unfulfilled               yes
# 2  #4746             paid  7/16/18 12:31        unfulfilled               yes
# 3  #4746             paid  7/16/18 12:31        unfulfilled               yes
# 4  #4746             paid  7/16/18 12:31        unfulfilled               yes
#
#   Currency  Subtotal  Shipping  Taxes   Total    ...     Refunded_Amount  \
# 0      USD     100.5     13.64    0.0  114.14    ...                 0.0
# 1      USD     100.5     13.64    0.0  114.14    ...                 NaN
# 2      USD     100.5     13.64    0.0  114.14    ...                 NaN
# 3      USD     100.5     13.64    0.0  114.14    ...                 NaN
# 4      USD     100.5     13.64    0.0  114.14    ...                 NaN
#
#              Vendor Tags Risk_Level  Source  \
# 0  US Jewelry House  NaN        Low     web
# 1  US Jewelry House  NaN        Low     web
# 2        impression  NaN        Low     web
# 3              Ella  NaN        Low     web
# 4           Stylist  NaN        Low     web
#
#                                      Lineitem_name.1        Color_  \
# 0                 Turquoise Crystal Rhinestone Ring           GDTQ
# 1                 Turquoise Crystal Rhinestone Ring           GDTQ
# 2  Tri Tone Cubic Zirconia Paved Simple Band Ring...        Size 8
# 3             Geometric Tortoise Link Long Necklace          Brown
# 4  Acetate Skinny Bangle Bracelet With Front Clos...   White/Brown
#
#    Unnamed:_39 Unnamed:_40 Tax_3_Name
# 0          NaN         NaN        NaN
# 1          NaN         NaN        NaN
# 2          NaN         NaN        NaN
# 3          NaN         NaN        NaN
# 4          NaN         NaN        NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ### Check NA's per columns

# %%
df.apply(lambda x: x.isna().sum()/len(df))
# Out:
# Name                           0.000000
# Financial_Status               0.000000
# Paid_at                        0.000000
# Fulfillment_Status             0.000000
# Accepts_Marketing              0.000000
# Currency                       0.000000
# Subtotal                       0.000000
# Shipping                       0.000000
# Taxes                          0.000000
# Total                          0.000000
# Discount_Code                  0.995263
# Discount_Amount                0.956404
# Shipping_Method                0.000000
# Created_at                     0.000000
# Lineitem_quantity              0.000000
# Lineitem_name                  0.000000
# Lineitem_price                 0.000000
# Lineitem_compare_at_price      0.917952
# Lineitem_sku                   0.519674
# Lineitem_fulfillment_status    0.000000
# Shipping_Street                0.000000
# Shipping_Address1              0.000000
# Shipping_Address2              0.000244
# Shipping_Company               0.000000
# Shipping_City                  0.000000
# Shipping_Zip                   0.000000
# Shipping_Province              0.000000
# Shipping_Country               0.000000
# Notes                          0.996928
# Note_Attributes                0.999988
# Cancelled_at                   0.999348
# Payment_Method                 0.000000
# Refunded_Amount                0.956404
# Vendor                         0.001571
# Tags                           0.999081
# Risk_Level                     0.000000
# Source                         0.000000
# Lineitem_name.1                0.000000
# Color_                         0.116741
# Unnamed:_39                    0.944347
# Unnamed:_40                    0.998324
# Tax_3_Name                     1.000000
# dtype: float64

# %% [markdown]
# ### Items with largest purchases in total quantity

# %%
df.groupby("Lineitem_name").agg({"Name":"count"}).sort_values("Name",ascending=0)
# Out:
#                                                     Name
# Lineitem_name
# Urban Geometric Metal Hoop Earrings - Gold           240
# Lightweight Urban Brass Earrings - Gold              174
# Urban Geometric Metal Hoop Earrings - Silver         164
# Lightweight Urban Brass Earrings - Silver            140
# Geometric Metal Hoop Earrings - Gold                 121
# Unisex Leather Bracelet                              119
# Lightweight Filigree Earrings - Gold                  99
# Urban Geometric Metal Hoop Earrings - Rose Gold       97
# Stering Silver Cubic Zirconia Studs Earrings - ...    84
# Bohemian Magnetic Bracelet                            84
# Lightweight Filigree Earrings - Rhodium               83
# Multi Charm Bohemian Choker - Black                   82
# Filigree Earrings - Gold                              79
# Lace Choker                                           76
# Stering Silver Cubic Zirconia Studs Earrings - ...    71
# Glass Stone Metal Choker                              69
# Lightweight Urban Brass Earrings - Rose Gold          67
# Pearl Mini Studs Earrings - Gold                      66
# Pearl Mini Studs Earrings - Rhodium                   64
# Colorful Pompom and Thread Tassel Statement Nec...    64
# Double Layered Pendant Choker                         63
# Rhinestone Bridal Cuff Bracelet - Gold                61
# Bridal Hair Comb                                      60
# Glass Stone Statement Earrings - Rhodium              57
# Cubic Zirconia Drop Hoop Earrings - Rhodium           57
# Lightweight Filigree Earrings - Matte Silver          57
# Urban Geometric Metal Hoop Earrings                   55
# Multi Chain Lightweight Choker Necklace Set - Gold    53
# Lightweight Filigree Earrings - Matte Gold            52
# Holiday Edition - Glass Statement Necklace - Clear    52
# ...                                                  ...
# Mesh Chain and Crystal Chunky Monique Necklace ...     1
# Mesh Chain and Crystals - Black                        1
# Medium Two Tone Organza Hat - Purple                   1
# Medium Sized Glass Beads Collar Necklace - Teal        1
# Medium Sinamay Hat With Large Loopy Floower - Tan      1
# Medium Brim Sinamy Hat With Loopy Center Piece ...     1
# Marquise Pendant Pearl Necklace - Gold                 1
# Marquise Pendant Pearl Necklace - Silver               1
# Marquise Stone Earrings - Gold                         1
# Matte Beads Linear Drop Earrings - Blue                1
# Matte Beads Linear Drop Earrings - Pink                1
# Matte Beads Linear Drop Earrings - White               1
# Matte Colored Vintage Frame Drop Earrings - Grey       1
# Matte Colored Vintage Frame Drop Earrings - White      1
# Matte Double Ball thread Tassel Drop Earrings -...     1
# Matte Enamel Ball Triple-Drop Earrings - Grey          1
# Matte Finish Double Teardrop Pendant Long Neckl...     1
# Matte Finish Double Teardrop Pendant Long Neckl...     1
# Matte Finish Half Metal Half Wood Circle Neckla...     1
# Matte Metal Print Diamond Shape Stud Earrings -...     1
# Matte Metal Print Marquise Shape Drop Earrings ...     1
# Matte Metal Print Marquise Shape Drop Earrings ...     1
# Matte Metal Print Marquise Shape Drop Earrings ...     1
# Matte Metal Print Teardrop Filigree Earrings - ...     1
# Matte Ring Holder - Jet                                1
# Matte Ring Holder - Silver                             1
# Medallion Pendant with Glass Beads Necklace            1
# Medium Brim Ruffle Organza Hat - Orange                1
# Medium Brim Sinamy Hat With Loopy Center Piece ...     1
# shawl3245gcl                                           1
#
# [26556 rows x 1 columns]

# %% [markdown]
# ### Items with largest purchases from differing orders

# %%
#Items from highest number of differing orders
df.groupby("Lineitem_name").agg({"Name": pd.Series.nunique}).sort_values("Name", ascending=False)
# Out:
#                                                     Name
# Lineitem_name
# Urban Geometric Metal Hoop Earrings - Gold           108
# Lightweight Urban Brass Earrings - Gold               99
# Lightweight Urban Brass Earrings - Silver             89
# Urban Geometric Metal Hoop Earrings - Silver          86
# Geometric Metal Hoop Earrings - Gold                  74
# Lightweight Filigree Earrings - Gold                  67
# Urban Geometric Metal Hoop Earrings - Rose Gold       56
# Filigree Earrings - Gold                              56
# Lightweight Filigree Earrings - Rhodium               56
# Lightweight Urban Brass Earrings - Rose Gold          55
# Unisex Leather Bracelet                               54
# Stering Silver Cubic Zirconia Studs Earrings - ...    53
# Bohemian Magnetic Bracelet                            52
# ALL COLORS RESTOCK! Suede Wrapping Choker - Black     50
# Lace Choker                                           48
# Rhinestone Bridal Cuff Bracelet - Gold                46
# Stering Silver Cubic Zirconia Studs Earrings - ...    44
# Boho Chic Multi Layered Metal Long Necklace - S...    41
# Lightweight Filigree Earrings - Matte Silver          41
# 6PCS Multi Lace Choker Set                            41
# ALL COLORS RESTOCK! Suede Wrapping Choker - Brown     40
# Urban Geometric Metal Hoop Earrings                   40
# Geometric Metal Hoop Earrings - Silver                40
# Glass Stone Statement Earrings - Rhodium              38
# Lightweight Filigree Earrings - Matte Gold            37
# Holiday Edition - Glass Statement Necklace - Clear    37
# ALL COLORS RESTOCK! Suede Wrapping Choker - Gray      37
# Holiday Edition - Glass Statement Necklace - Blue     36
# Multi Chain Lightweight Choker Necklace Set - Gold    36
# Colorful Pompom and Thread Tassel Statement Nec...    36
# ...                                                  ...
# Mesh Chain Hard Earrings                               1
# Mesh Chain and Crystal Chunky Monique Necklace ...     1
# Medium Sized Glass Beads Collar Necklace - Teal        1
# Medium Sinamay Hat With Large Loopy Floower - Tan      1
# Medium Brim Sinamy Hat With Loopy Center Piece ...     1
# Medium Brim Sinamy Hat With Loopy Center Piece ...     1
# Marquise Long Drop Earrings - Gold                     1
# Marquise Pendant Pearl Necklace - Gold                 1
# Marquise Pendant Pearl Necklace - Silver               1
# Marquise Stone Earrings - Gold                         1
# Matte Beads Linear Drop Earrings - Blue                1
# Matte Beads Linear Drop Earrings - Pink                1
# Matte Beads Linear Drop Earrings - White               1
# Matte Colored Vintage Frame Drop Earrings - Grey       1
# Matte Colored Vintage Frame Drop Earrings - White      1
# Matte Double Ball thread Tassel Drop Earrings -...     1
# Matte Enamel Ball Triple-Drop Earrings - Grey          1
# Matte Finish Double Teardrop Pendant Long Neckl...     1
# Matte Finish Double Teardrop Pendant Long Neckl...     1
# Matte Finish Half Metal Half Wood Circle Neckla...     1
# Matte Metal Print Diamond Shape Stud Earrings -...     1
# Matte Metal Print Marquise Shape Drop Earrings ...     1
# Matte Metal Print Marquise Shape Drop Earrings ...     1
# Matte Metal Print Marquise Shape Drop Earrings ...     1
# Matte Metal Print Teardrop Filigree Earrings - ...     1
# Matte Ring Holder - Jet                                1
# Matte Ring Holder - Silver                             1
# Medallion Pendant with Glass Beads Necklace            1
# Medium Brim Ruffle Organza Hat - Orange                1
# shawl3245gcl                                           1
#
# [26556 rows x 1 columns]

# %% [markdown]
# ### Checking words with highest occurence in orders

# %%
"".join(df.Lineitem_name.unique()).split()
# Out:
# ['Turquoise',
#  'Crystal',
#  'Rhinestone',
#  'Ring',
#  '-',
#  'GDTQTri',
#  'Tone',
#  'Cubic',
#  'Zirconia',
#  'Paved',
#  'Simple',
#  'Band',
#  'Ring',
#  'Set',
#  '-',
#  'Size',
#  '8Geometric',
#  'Tortoise',
#  'Link',
#  'Long',
#  'Necklace',
#  '-',
#  'BrownAcetate',
#  'Skinny',
#  'Bangle',
#  'Bracelet',
#  'With',
#  'Front',
#  'Closure',
#  '-',
#  'White/BrownModern',
#  'Acetate',
#  'Hoop',
#  'Earrings',
#  '-',
#  'MultiKnot',
#  'Ear',
#  'Studs',
#  '-',
#  'GoldTexture',
#  'Link',
#  'Earrings',
#  '-',
#  'GoldHemisphere',
#  'Mini',
#  'Studs',
#  'Earrings',
#  '-',
#  'MultiLightweight',
#  'Geometric',
#  'Bar',
#  'Hoop',
#  'Earrings',
#  '-',
#  'SGSGSemi',
#  'Precious',
#  'Beads',
#  'Linear',
#  'Drop',
#  'Earrings',
#  '-',
#  'GDPKCubic',
#  'Zirconia',
#  'Studs',
#  'Earrings',
#  '-',
#  'GDPLMulti',
#  'Color',
#  'Glass',
#  'Stone',
#  'Drop',
#  'Earrings',
#  '-',
#  'Black',
#  'DiamondMulti',
#  'Color',
#  'Glass',
#  'Stone',
#  'Drop',
#  'Earrings',
#  '-',
#  'BrownLong',
#  'Teardrop',
#  'Shape',
#  'Lucite',
#  'Drop',
#  'EarringsHoop',
#  'Acetate',
#  'Linked',
#  'Drop',
#  'Earrings',
#  '-',
#  'BlueGeometric',
#  'Acetate',
#  'Linked',
#  'Drop',
#  'Earrings',
#  '-',
#  'Ivory',
#  'Black',
#  'BrownGeometric',
#  'Acetate',
#  'Linked',
#  'Drop',
#  'Earrings',
#  '-',
#  'MultiGeometric',
#  'Metal',
#  'And',
#  'Acetate',
#  'Hoop',
#  'Drop',
#  'Earrings',
#  '-',
#  'Beige',
#  '2Urban',
#  'Metal',
#  'Bar',
#  'Acetate',
#  'Hoop',
#  'Earrings',
#  '-',
#  'IvoryUrban',
#  'Lightweight',
#  'Irregular',
#  'Hoop',
#  'Drop',
#  'Earrings',
#  '-',
#  'Worn',
#  'SilverOval',
#  'Glass',
#  'Stone',
#  'Thread',
#  'Tassel',
#  'Statement',
#  'Earrings',
#  '-',
#  'PinkOval',
#  'Glass',
#  'Stone',
#  'Thread',
#  'Tassel',
#  'Statement',
#  'Earrings',
#  '-',
#  'BlackGlass',
#  'Stone',
#  'Thread',
#  'Tassel',
#  'Statement',
#  'Earrings',
#  '-',
#  'IvoryGlass',
#  'Stone',
#  'Thread',
#  'Tassel',
#  'Statement',
#  'Earrings',
#  '-',
#  'BlackGlass',
#  'Stone',
#  'Circle',
#  'Thread',
#  'Tassel',
#  'Earrings',
#  '-',
#  'BlueGlass',
#  'Stone',
#  'Circle',
#  'Thread',
#  'Tassel',
#  'Earrings',
#  '-',
#  'IvoryGlass',
#  'Stone',
#  'Circle',
#  'Thread',
#  'Tassel',
#  'Earrings',
#  '-',
#  'PinkThreaded',
#  'Disc',
#  'Tassel',
#  'Fan',
#  'Drop',
#  'Earrings',
#  '-',
#  'PinkThreaded',
#  'Disc',
#  'Tassel',
#  'Fan',
#  'Drop',
#  'Earrings',
#  '-',
#  'MintCactus',
#  'Textured',
#  'Metal',
#  'Mini',
#  'Tassel',
#  'Earrings',
#  '-',
#  'YellowChain',
#  'Wrapped',
#  'Long',
#  'Tassel',
#  'Earrings',
#  '-',
#  'IvoryChain',
#  'Wrapped',
#  'Long',
#  'Tassel',
#  'Earrings',
#  '-',
#  'GreyChain',
#  'Wrapped',
#  'Long',
#  'Tassel',
#  'Earrings',
#  '-',
#  'BlackChain',
#  'Wrapped',
#  'Long',
#  'Tassel',
#  'Earrings',
#  '-',
#  'PeachVivid',
#  'Summer',
#  'Edition',
#  'Acetate',
#  'Teardrop',
#  'Hoop',
#  'Glass',
#  'Stone',
#  'EarringsModern',
#  'Acrylic',
#  'Cuff',
#  'Bracelet',
#  '-',
#  'Ivory/Brown-6Modern',
#  'Acrylic',
#  'Cuff',
#  'Bracelet',
#  '-',
#  'Blue-7Gold',
#  'Dipped',
#  'Semi',
#  'Precious',
#  'Stone',
#  'Bar',
#  'Simple',
#  'Long',
#  'Necklace',
#  '-',
#  'WhiteGold',
#  'Dipped',
#  'Semi',
#  'Precious',
#  'Stone',
#  'Bar',
#  'Simple',
#  'Long',
#  'Necklace',
#  '-',
#  'GreyTurquoise',
#  'Arrowhead',
#  'Pendant',
#  'Long',
#  'NecklaceBasket',
#  'Weave',
#  'Linked',
#  'Straw',
#  'Disc',
#  'Short',
#  'Necklace',
#  '-',
#  'BeigeAztec',
#  'Lightweight',
#  'Patterned',
#  'Filigree',
#  'Earrings',
#  '-',
#  'RhodiumAztec',
#  'Lightweight',
#  'Patterned',
#  'Filigree',
#  'Earrings',
#  '-',
#  'GoldDruzy',
#  'Charm',
#  'Hoop',
#  'Drop',
#  'Earrings',
#  '-',
#  'BeigeModern',
#  'Flat',
#  'Acetate',
#  'Hoop',
#  'Earrings',
#  '(Large)',
#  '-',
#  'MultiHalf',
#  'Disc',
#  'Acetate',
#  'Hoop',
#  'Earrings',
#  '-',
#  'BrownUrban',
#  'Geometric',
#  'Acetate',
#  'Bar',
#  'Fringe',
#  'Earrings',
#  '-',
#  'Grey',
#  'MultiTwo',
#  'Tone',
#  'Acetate',
#  'Oval',
#  'Hoop',
#  'Drop',
#  'Earrings',
#  '-',
#  'Ivory',
#  '1SISTERS',
#  'Inspirational',
#  'Tri',
#  'Tone',
#  'Ring',
#  'SetSTAY',
#  'STRONG',
#  'Inspirational',
#  'Tri',
#  'Tone',
#  'Ring',
#  'SetLOVE',
#  'Inspirational',
#  'Tri',
#  'Tone',
#  'Ring',
#  'SetPlaid',
#  'Square',
#  'Scarf',
#  'with',
#  'Fringe',
#  '-',
#  'BGUrban',
#  'Hammered',
#  'Cuff',
#  'Bracelet',
#  '-',
#  'RhodiumCrumpled',
#  'Plate',
#  'Mini',
#  'Studs',
#  'EarringsPremium',
#  'Cubic',
#  'Zirconia',
#  'Mini',
#  'Triangle',
#  'Stud',
#  'Earrings',
#  '-',
#  'GoldMini',
#  'Acrylic',
#  'Disc',
#  'Stud',
#  'Earrings',
#  '-',
#  'PinkVivid',
#  'Summer',
#  'Edition',
#  'Acrylic',
#  'Bee',
#  'Statement',
#  'Necklace',
#  '-',
#  'CreamDouble',
#  'Layer',
#  'Mini',
#  'Glass',
#  'Bead',
#  'Semi',
#  'Precious',
#  'Stone',
#  'Pendant',
#  'Necklace',
#  '-',
#  'White',
#  'PearlDouble',
#  'Layer',
#  'Mini',
#  'Glass',
#  'Bead',
#  'Semi',
#  'Precious',
#  'Stone',
#  'Pendant',
#  'Necklace',
#  '-',
#  'Light',
#  'Colorado',
#  'TopazDouble',
#  'Layer',
#  'Mini',
#  'Glass',
#  'Bead',
#  'Semi',
#  'Precious',
#  'Stone',
#  'Pendant',
#  'Necklace',
#  '-',
#  'BlueSeed',
#  'Beaded',
#  'Circle',
#  'Pendant',
#  'Long',
#  'Chain',
#  'Necklace',
#  '-',
#  'BeigeTwo',
#  'Tone',
#  'Leather',
#  'Disc',
#  'Drop',
#  'Earrings',
#  '-',
#  'Matte',
#  'GoldLightweight',
#  'Flat',
#  'Acetate',
#  'Hoop',
#  'Earrings',
#  '(Large)',
#  '-',
#  'PinkSeed',
#  'Beaded',
#  'Multi',
#  'Strand',
#  'Side',
#  'Knot',
#  'Necklace',
#  '-',
#  'Mint',
#  'BlueFabric',
#  'Flower',
#  'Petal',
#  'Wooden',
#  'Bead',
#  'Short',
#  'Necklace',
#  '-',
#  'BlueFabric',
#  'Flower',
#  'Petal',
#  'Wooden',
#  'Bead',
#  'Short',
#  'Necklace',
#  '-',
#  'BlackFabric',
#  'Flower',
#  'Petal',
#  'Wooden',
#  'Bead',
#  'Short',
#  'Necklace',
#  '-',
#  'IvoryGRACE',
#  'Inspirational',
#  'Message',
#  'Bracelet',
#  '-',
#  'GoldI',
#  'Love',
#  'You',
#  'to',
#  'the',
#  'Moon',
#  'and',
#  'Back',
#  'Pendant',
#  'Necklace',
#  '-',
#  'GoldI',
#  'Love',
#  'You',
#  'to',
#  'the',
#  'Moon',
#  'and',
#  'Back',
#  'Pendant',
#  'Necklace',
#  '-',
#  'RhodiumBELIEVE.',
#  'HOPE.',
#  'FAITH',
#  'Inspirational',
#  'Message',
#  'Bracelet',
#  '-',
#  'SilverFlattened',
#  'Skinny',
#  'Metal',
#  'Bangle',
#  'Bracelet',
#  'Set',
#  '-',
#  'GoldPIECE',
#  'LOVE',
#  'HAPPINESS',
#  'Inspirational',
#  'Message',
#  'Bracelet',
#  '-',
#  'RhodiumCubic',
#  'Zirconia',
#  '5',
#  'Row',
#  'Wide',
#  'Huggies',
#  'Hoop',
#  'Earrings',
#  '-',
#  'RhodiumKEEP',
#  'DREAMING',
#  'Inspirational',
#  'Message',
#  'Bracelet',
#  '-',
#  'RhodiumTHINK',
#  'HAPPY',
#  'Inspirational',
#  'Message',
#  'Bracelet',
#  '-',
#  'RhodiumBlessed',
#  'Rhinestone',
#  'Tape',
#  'KeychainOwl',
#  'Mirror',
#  'Keychain',
#  '-',
#  'YellowHOPE',
#  '-Message',
#  'Bracelet',
#  '-',
#  'RhodiumBEACH',
#  'GIRL',
#  'Inspirational',
#  'Message',
#  'Bracelet',
#  '-',
#  'RhodiumLOVE',
#  'IS',
#  'LOVE',
#  'Inspirational',
#  'Message',
#  'Bracelet',
#  '-',
#  'RhodiumTriple',
#  'Hammered',
#  'Metal',
#  'Bracelet',
#  '-',
#  'SilverTriple',
#  'Hammered',
#  'Metal',
#  'Bracelet',
#  '-',
#  'GoldGeometric',
#  'Acetate',
#  'Oval',
#  'Pendant',
#  'Long',
#  'Necklace',
#  '-',
#  'MultiGeometric',
#  'Acetate',
#  'Oval',
#  'Pendant',
#  'Long',
#  'Necklace',
#  '-',
#  'WhiteGeometric',
#  'Acetate',
#  'Oval',
#  'Pendant',
#  'Long',
#  'Necklace',
#  '-',
#  'NaturalVintage',
#  'Frame',
#  'Laser',
#  'Cut',
#  'Metal',
#  'Paved',
#  'Leather',
#  'Earrings',
#  '-',
#  'BrownVintage',
#  'Frame',
#  'With',
#  'Tassel',
#  'Laser',
#  'Cut',
#  'Metal',
#  'Paved',
#  'Leather',
#  'Pendant',
#  'Necklace',
#  '-',
#  'BrownRaw',
#  'Natural',
#  'Stone',
#  'Glass',
#  'Beaded',
#  'Bracelet',
#  'Set',
#  '-',
#  'BlackTwo-Tone',
#  'Metal',
#  'Round',
#  'Drop',
#  'Earrings',
#  '-',
#  'GoldCrispy',
#  'Textured',
#  'Leaf',
#  'Pendant',
#  'Long',
#  'Necklace',
#  '-',
#  'Rose',
#  'GoldCrispy',
#  'Textured',
#  'Leaf',
#  'Pendant',
#  'Long',
#  'Necklace',
#  '-',
#  'GoldSemi',
#  'Precious',
#  'Stone',
#  'Beaded',
#  'Freshwater',
#  'Pearl',
#  'Tassel',
#  'Long',
#  'Necklace',
#  '-',
#  'IvorySemi',
#  'Precious',
#  'Stone',
#  'Clover',
#  'With',
#  'Chain',
#  'Tassel',
#  'Long',
#  'Necklace',
#  '-',
#  'TurquoiseSimple',
#  'Vertical',
#  'Bar',
#  'Long',
#  'Chain',
#  'Necklace',
#  '-',
#  'Burnished',
#  'SilverSimple',
#  'Vertical',
#  'Bar',
#  'Long',
#  'Chain',
#  'Necklace',
#  '-',
#  'Matte',
#  'GoldNatural',
#  'Stone',
#  'Long',
#  'Necklace',
#  '72"',
#  '-',
#  'TurquoiseNatural',
#  'Stone',
#  'Long',
#  'Necklace',
#  '72"',
#  '-',
#  'CoralNatural',
#  'Stone',
#  'Long',
#  'Necklace',
#  '90"',
#  '-',
#  'PearlMetal',
#  'Carved',
#  'Semi',
#  'Precious',
#  'Stone',
#  'Disc',
#  'Pendant',
#  'Necklace',
#  '-',
#  'TurquoiseBoho',
#  'Chic',
#  'Glass',
#  'Stone',
#  'Thread',
#  'Tassel',
#  'Long',
#  'Necklace',
#  '-',
#  'BlueBoho',
#  'Chic',
#  'Glass',
#  'Stone',
#  'Thread',
#  'Tassel',
#  'Long',
#  'Necklace',
#  '-',
#  'IvorySemi',
#  'Precious',
#  'Multi',
#  'Beads',
#  'Bohemian',
#  'Necklace',
#  '-',
#  'MultiMulti',
#  'Functional',
#  'Glass',
#  'Beads',
#  'Wrapping',
#  'Necklace',
#  '-',
#  'TurquoiseBeaded',
#  'Drop',
#  'Pendant',
#  'Long',
#  'Necklace',
#  '-',
#  'Gold-PearlBeaded',
#  'Drop',
#  'Pendant',
#  'Long',
#  'Necklace',
#  '-',
#  'Gold-TurquoiseRhinestone',
#  'Embellished',
#  'Longhorn',
#  'Pendant',
#  'Beaded',
#  'Lariat',
#  'NecklaceHammered',
#  'Mini',
#  'Leaf',
#  'Metal',
#  'Beaded',
#  'Short',
#  'Necklace',
#  '-',
#  'Worn',
#  'Gold/Worn',
#  'SilverGeometric',
#  'Triple',
#  'Strand',
#  'Aluminium',
#  'And',
#  'Glass',
#  'Charm',
#  'Short',
#  'NecklaceBasket',
#  'Weave',
#  'Straw',
#  'Hoop',
#  'Pendant',
#  'Long',
#  'Necklace',
#  '-',
#  'BeigeFun',
#  'Pencil',
#  'Crossbody',
#  'Bag',
#  '-',
#  'YellowFun',
#  'Pencil',
#  'Crossbody',
#  'Bag',
#  '-',
#  'RedSeed',
#  'Beaded',
#  'Disc',
#  'Drop',
#  'Earrings',
#  '-',
#  'IvoryMulti',
#  'Strand',
#  'Fish',
#  'Wire',
#  'Seed',
#  'Beaded',
#  'NecklaceGeometric',
#  'Beaded',
#  'Earrings',
#  '-',
#  'ATriple',
#  'Stations',
#  'Seed',
#  'Beads',
#  'Hippie',
#  'Necklace',
#  '-',
#  'MultiBoho',
#  'Chic',
#  'Genuine',
#  'Leather',
#  'Magnetic',
#  'Bracelet',
#  '-',
#  'TopazBoho',
#  'Chic',
#  'Bamboo',
#  'knot',
#  'Pendant',
#  'Long',
#  'NecklaceEmbroidery',
#  'Multi',
#  'Colored',
#  'Pom',
#  'Pom',
#  'Clutch',
#  'Bag',
#  '-',
#  'BKDouble',
#  'Zipper',
#  'Leather',
#  'Tassel',
#  'Waist',
#  'Bag',
#  '-',
#  'BlackCloie',
#  'Limited',
#  'Edition',
#  'Wooden',
#  'Round',
#  'Clutch',
#  'Bag',
#  '-',
#  'BrownBasket',
#  'Weave',
#  'Straw',
#  'Disc',
#  'Pendant',
#  'Long',
#  'Necklace',
#  '-',
#  'BeigeSpaced',
#  'Acetate',
#  'Link',
#  'Circle',
#  'Pendant',
#  'Long',
#  'NecklaceFloral',
#  'Cluster',
#  'Acrylic',
#  'Hoop',
#  'Drop',
#  'Earrings',
#  '-',
#  'MultiBoho',
#  'Chic',
#  'Lightweight',
#  'Wood',
#  'Pendant',
#  'Long',
#  'NecklaceUrban',
#  'Geometric',
#  'Metal',
#  'Pendant',
#  'Long',
#  'Necklace',
#  '-',
#  'Gold',
#  'SilverSpaced',
#  'Metal',
#  'Disc',
#  'Layered',
#  'Leather',
#  'Cord',
#  'Long',
#  'Necklace',
#  '-',
#  'BlackModern',
#  'Geometric',
#  'Short',
#  'Collar',
#  'NecklaceVivid',
#  'Summer',
#  'Edition',
#  'Acetate',
#  'Link',
#  'Statement',
#  'Necklace',
#  '-',
#  'MultiUrban',
#  'Geometric',
#  'Two',
#  'Layer',
#  'Aluminium',
#  'Disc',
#  'Short',
#  'Necklace',
#  '-',
#  'BrownMulti',
#  'Color',
#  'Geometric',
#  'Disc',
#  'Pendant',
#  'Short',
#  'NecklaceGeometric',
#  'Raw',
#  'Natural',
#  'Stone',
#  'Chunky',
#  'Short',
#  'Collar',
#  'NecklaceModern',
#  'Double',
#  'Layer',
#  'Spaced',
#  'Geometric',
#  'Charm',
#  'Long',
#  'NecklaceModern',
#  'Geometric',
#  'Acetate',
#  'And',
#  'Wood',
#  'Sliding',
#  'Charm',
#  'Short',
#  'Necklace',
#  '-',
#  'BlackNature',
#  'Inspired',
#  'Long',
#  'Wooden',
#  'Bead',
#  'Short',
#  'Necklace',
#  '-',
#  'BrownTurquoise',
#  'Seed',
#  'Beaded',
#  'Disc',
#  'Drop',
#  'EarringsSemi-Precious',
#  'Stone',
#  'Bead',
#  'Two',
#  'Tone',
#  'Metal',
#  'Pendant',
#  'Long',
#  'Necklace',
#  '-',
#  'AmazoniteSeed',
#  'Beaded',
#  'Side',
#  'Knot',
#  'Multi',
#  'Strand',
#  'Long',
#  'Necklace',
#  '-',
#  'PinkSeed',
#  'Beaded',
#  'Side',
#  'Knot',
#  'Multi',
#  'Strand',
#  'Long',
#  'Necklace',
#  '-',
#  'IvoryBohemian',
#  'Long',
#  'Beaded',
#  'Necklace',
#  'With',
#  'Metal',
#  'Chain',
#  'Fringe',
#  '-',
#  'MultiMatte',
#  'Finish',
#  'Half',
#  'Metal',
#  ...]

# %%
#Create a dictionary to see words with highest occurence in orders
item_string = " ".join(df.Lineitem_name.unique()).split()
item_dict = {}

for i in item_string:
    if i in item_dict.keys():
        item_dict[i] += 1
    else:
        item_dict[i] = 1
        
del item_dict['-']
print(item_dict)

#turning dictionary into dataframe
item_wordcount = pd.DataFrame(pd.Series(item_dict)).rename(columns = {0:"word_count"})
item_wordcount = item_wordcount.sort_values("word_count", ascending=False)
item_wordcount = item_wordcount.drop("-", axis=0)

#plotting results
plot_wordcount = item_wordcount.head(15)
plot_wordcount.sort_values('word_count', ascending=1).plot(kind="barh")
# Out:
# {'Turquoise': 825, 'Crystal': 520, 'Rhinestone': 1158, 'Ring': 534, 'GDTQ': 34, 'Tri': 64, 'Tone': 229, 'Cubic': 759, 'Zirconia': 774, 'Paved': 105, 'Simple': 563, 'Band': 11, 'Set': 798, 'Size': 197, '8': 23, 'Geometric': 1438, 'Tortoise': 360, 'Link': 271, 'Long': 2025, 'Necklace': 8472, 'Brown': 613, 'Acetate': 288, 'Skinny': 53, 'Bangle': 133, 'Bracelet': 2992, 'With': 174, 'Front': 36, 'Closure': 47, 'White/Brown': 1, 'Modern': 147, 'Hoop': 1685, 'Earrings': 8796, 'Multi': 2439, 'Knot': 379, 'Ear': 260, 'Studs': 1289, 'Gold': 4235, 'Texture': 78, 'Hemisphere': 6, 'Mini': 1539, 'Lightweight': 1012, 'Bar': 759, 'SGSG': 19, 'Semi': 1121, 'Precious': 1118, 'Beads': 2464, 'Linear': 505, 'Drop': 2381, 'GDPK': 18, 'GDPL': 13, 'Color': 485, 'Glass': 2806, 'Stone': 3633, 'Black': 1685, 'Diamond': 269, 'Teardrop': 784, 'Shape': 336, 'Lucite': 37, 'Linked': 115, 'Blue': 929, 'Ivory': 795, 'Metal': 2026, 'And': 154, 'Beige': 319, '2': 83, 'Urban': 730, 'Irregular': 44, 'Worn': 273, 'Silver': 2322, 'Oval': 360, 'Thread': 1336, 'Tassel': 2996, 'Statement': 1086, 'Pink': 800, 'Circle': 241, 'Threaded': 5, 'Disc': 279, 'Fan': 64, 'Mint': 438, 'Cactus': 20, 'Textured': 105, 'Yellow': 164, 'Chain': 1293, 'Wrapped': 343, 'Grey': 356, 'Peach': 364, 'Vivid': 234, 'Summer': 198, 'Edition': 247, 'Acrylic': 92, 'Cuff': 599, 'Ivory/Brown-6': 1, 'Blue-7': 1, 'Dipped': 46, 'White': 695, 'Arrowhead': 13, 'Pendant': 2856, 'Basket': 7, 'Weave': 52, 'Straw': 70, 'Short': 392, 'Aztec': 66, 'Patterned': 48, 'Filigree': 422, 'Rhodium': 1676, 'Druzy': 630, 'Charm': 1179, 'Flat': 121, '(Large)': 30, 'Half': 102, 'Fringe': 802, 'Two': 222, '1': 53, 'SISTERS': 6, 'Inspirational': 121, 'STAY': 13, 'STRONG': 13, 'LOVE': 84, 'Plaid': 63, 'Square': 245, 'Scarf': 383, 'with': 1095, 'BG': 14, 'Hammered': 264, 'Crumpled': 12, 'Plate': 197, 'Premium': 103, 'Triangle': 354, 'Stud': 481, 'Bee': 21, 'Cream': 57, 'Double': 803, 'Layer': 70, 'Bead': 276, 'Pearl': 892, 'Light': 175, 'Colorado': 50, 'Topaz': 292, 'Seed': 670, 'Beaded': 846, 'Leather': 781, 'Matte': 323, 'Strand': 298, 'Side': 66, 'Fabric': 144, 'Flower': 949, 'Petal': 31, 'Wooden': 178, 'GRACE': 3, 'Message': 470, 'I': 79, 'Love': 75, 'You': 23, 'to': 17, 'the': 50, 'Moon': 106, 'and': 950, 'Back': 31, 'BELIEVE.': 2, 'HOPE.': 2, 'FAITH': 28, 'Flattened': 3, 'PIECE': 3, 'HAPPINESS': 6, '5': 60, 'Row': 38, 'Wide': 52, 'Huggies': 3, 'KEEP': 8, 'DREAMING': 1, 'THINK': 1, 'HAPPY': 4, 'Blessed': 8, 'Tape': 24, 'Keychain': 232, 'Owl': 20, 'Mirror': 15, 'HOPE': 29, '-Message': 20, 'BEACH': 2, 'GIRL': 3, 'IS': 22, 'Triple': 397, 'Natural': 1138, 'Vintage': 65, 'Frame': 95, 'Laser': 19, 'Cut': 256, 'Raw': 7, 'Two-Tone': 7, 'Round': 651, 'Crispy': 10, 'Leaf': 305, 'Rose': 838, 'Freshwater': 26, 'Clover': 32, 'Vertical': 8, 'Burnished': 1, '72"': 3, 'Coral': 172, '90"': 1, 'Carved': 22, 'Boho': 356, 'Chic': 357, 'Bohemian': 1083, 'Functional': 180, 'Wrapping': 203, 'Gold-Pearl': 2, 'Gold-Turquoise': 4, 'Embellished': 56, 'Longhorn': 6, 'Lariat': 94, 'Gold/Worn': 5, 'Aluminium': 21, 'Fun': 24, 'Pencil': 2, 'Crossbody': 31, 'Bag': 329, 'Red': 300, 'Fish': 87, 'Wire': 111, 'A': 35, 'Stations': 6, 'Hippie': 8, 'Genuine': 237, 'Magnetic': 220, 'Bamboo': 28, 'knot': 2, 'Embroidery': 68, 'Colored': 63, 'Pom': 294, 'Clutch': 389, 'BK': 54, 'Zipper': 12, 'Waist': 2, 'Cloie': 16, 'Limited': 16, 'Spaced': 26, 'Floral': 35, 'Cluster': 267, 'Wood': 85, 'Layered': 1009, 'Cord': 226, 'Collar': 479, 'Chunky': 205, 'Sliding': 261, 'Nature': 24, 'Inspired': 138, 'Semi-Precious': 41, 'Amazonite': 17, 'Finish': 27, 'Satin': 95, 'Rectangular': 95, 'Olive/Brown': 1, 'Marble': 157, 'Print': 131, 'Green': 267, 'Stones': 70, 'on': 60, 'Hammer': 1, 'Clear': 304, 'Oversized': 176, 'Holographic': 10, 'Glitter': 106, 'Faceted': 134, 'Dotted': 8, 'Mustard': 15, 'Navy': 206, 'Core': 22, '(Medium)': 10, 'Cutout': 184, 'Tear': 23, 'beaded': 2, 'bead': 4, 'Raffia': 64, 'Fuchsia': 88, 'Nude': 21, 'Teal': 30, 'Ark': 12, 'Handbag': 31, 'Namaste': 4, '-Ins ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-390fa6234884> in <module>()
#      15 item_wordcount = pd.DataFrame(pd.Series(item_dict)).rename(columns = {0:"word_count"})
#      16 item_wordcount = item_wordcount.sort_values("word_count", ascending=False)
# ---> 17 item_wordcount = item_wordcount.drop("-", axis=0)
#      18
#      19 #plotting results
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3109
#    3110         if inplace:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3138                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3139             else:
# -> 3140                 new_axis = axis.drop(labels, errors=errors)
#    3141             dropped = self.reindex(**{axis_name: new_axis})
#    3142             try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4385             if errors != 'ignore':
#    4386                 raise KeyError(
# -> 4387                     'labels %s not contained in axis' % labels[mask])
#    4388             indexer = indexer[~mask]
#    4389         return self.delete(indexer)
#
# KeyError: "labels ['-'] not contained in axis"
