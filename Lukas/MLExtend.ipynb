# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from apyori import apriori
plt.style.use('ggplot')

# %%
df = pd.read_pickle('USJH.pkl')

# %%
df2 = df[['name', 'lineitem_name', 'category']]

# %%
grouped_df = df.groupby('name')['lineitem_name']

# %%
lis = []
for key, item in grouped_df:
    lis.append(list(item))

# %%
lis[:5]
# Out:
# [['cross bracelet', 'tassel and beads', 'glass beads-tassel - turquoise'],
#  ['mesh chain and crystals - black', 'heartbeat'],
#  ['tied up cord and thread necklace - black'],
#  ['jewelry display mannequin-torso - white',
#   'jewelry display mannequin-torso - black'],
#  ['all about detail-necklace - ivory', 'all about detail-necklace - black']]

# %%
from mlxtend.preprocessing import TransactionEncoder

oht_ary = te.fit(lis).transform(lis, sparse=True)
sparse_df = pd.SparseDataFrame(te_ary, columns=te.columns_, default_fill_value=False)
sparse_df
# Out:
#       "flawless" make up inspired clutch  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
# 17                                 False
# 18                                 False
# 19                                 False
# 20                                 False
# 21                                 False
# ...

# %%
c = apriori(sparse_df, min_support=0.01, use_colnames=True)

# %%
frequent_itemsets = apriori(sparse_df, min_support=0.6, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-baf3a4b05460> in <module>()
#       1 frequent_itemsets = apriori(sparse_df, min_support=0.6, use_colnames=True)
# ----> 2 frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
#       3 frequent_itemsets
#
# TypeError: 'generator' object is not subscriptable

# %%
list(c)
