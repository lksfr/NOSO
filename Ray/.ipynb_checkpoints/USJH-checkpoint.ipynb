# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 1000)

# %%
#df = pd.read_csv("USJH_order_dataset.csv")
# Out:
# C:\Users\rayl1\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (18,29,30,34,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = pd.read_pickle("../Lukas/USJH.pkl")

# %% [markdown]
# ### Formatting dataframe

# %%
def format_header(df):
    df.columns = df.columns.str.lower()
    df.columns = df.columns.str.replace(" ","_")
    return df

# %%
def cols_to_datetime(df, date_col=["paid_at", "created_at"]):
    df.loc[:,date_col] = df.loc[:,date_col].apply(lambda x: pd.to_datetime(x))
    return df

# %%
df = format_header(df)
df = cols_to_datetime(df)

# %%
df[["paid_at", "created_at"]].dtypes
# Out:
# paid_at       datetime64[ns]
# created_at    datetime64[ns]
# dtype: object

# %% [markdown]
# ### Creating new columns to analyze date and times for "created_at" column

# %%
#create new time columns
def created_at_cols(df):
    df["created_at_yr_mo"] = df["created_at"].dt.to_period("M")
    df["created_at_yr_mo_day"] = df["created_at"].dt.to_period("D")
    df["created_at_hour"] = df["created_at"].dt.hour
    df["created_at_yr"] = df["created_at"].dt.year
    return df

# %%
df.groupby(["created_at_yr_mo", "lineitem_name"]).agg({"name":"count"}).sort_values("name", ascending=False)
# Out:
#                                                                      name
# created_at_yr_mo lineitem_name
# 2018-01          urban geometric metal hoop earrings - gold            85
# 2017-12          urban geometric metal hoop earrings - gold            68
# 2018-01          urban geometric metal hoop earrings - silver          65
# 2017-11          lightweight urban brass earrings - gold               61
# 2017-12          urban geometric metal hoop earrings - silver          45
#                  lightweight urban brass earrings - silver             41
# 2017-11          geometric metal hoop earrings - gold                  41
# 2017-12          lightweight urban brass earrings - gold               39
# 2018-01          lightweight urban brass earrings - gold               38
# 2017-11          lightweight urban brass earrings - silver             37
# 2017-06          bohemian magnetic bracelet                            37
# 2017-11          cubic zirconia drop hoop earrings - rhodium           36
#                  cubic zirconia drop hoop earrings - rose gold         35
# 2018-01          urban geometric metal hoop earrings - rose gold       34
#                  lightweight urban brass earrings - silver             34
# 2016-06          double layered pendant choker                         32
# 2018-03          urban geometric metal hoop earrings - gold            28
# 2018-01          urban geometric metal hoop earrings                   27
# 2017-11          multi chain lightweight choker necklace set - gold    27
#                  filigree earrings - gold                              26
# 2016-12          glass stone metal choker                              26
# 2017-04          pearl mini studs earrings - rhodium                   25
# 2018-01          stering silver cubic zirconia studs earrings - ...    24
# 2017-10          geometric metal hoop earrings - gold                  24
#                  rhinestone genuine leather magnetic bracelet          24
# 2017-11          lightweight urban brass earrings - rose gold          22
#                  multi chain lightweight choker necklace set - r...    22
# 2017-02          lightweight filigree earrings - gold                  22
# 2017-11          knit beanie with pom pom hat - grey                   22
# 2017-05          thread ball linear drop earrings - blue               21
# ...                                                                   ...
# 2017-04          embroidered pineapple straw hat - beige                1
#                  embroidered pineapple straw hat - ivory                1
#                  embroidery and fringe cover up - ivory                 1
#                  embroidery vest - pink                                 1
#                  enjoy the journey message bracelet - gold              1
#                  dual pompom earrings - white                           1
#                  druzy stone ring - chalcedony                          1
#                  druzy cascade earrings - hematite                      1
#                  druzy stone latch bracelet - fuchsia                   1
#                  druzy cascade earrings - opal pink                     1
#                  druzy cascade earrings - silver bubble                 1
#                  druzy cascade earrings - silver hematite               1
#                  druzy needleback earrings - fuchsia                    1
#                  druzy needleback earrings - hematite                   1
#                  druzy needleback earrings - navy blue                  1
#                  druzy stone and tassel necklace - pink                 1
#                  druzy stone latch bracelet - black                     1
#                  druzy stone latch bracelet - bubble aurore boreale     1
#                  druzy stone latch bracelet - peach                     1
#                  druzy stone ring - bubble                              1
#                  druzy stone latch bracelet - rose gold                 1
#                  druzy stone latch bracelet - silver                    1
#                  druzy stone pendant long necklace - black              1
#                  druzy stone pendant long necklace - blue aurore...     1
#                  druzy stone pendant long necklace - pink               1
#                  druzy stone pendant long necklace - rose gold          1
#                  druzy stone pendant with glass beads necklace -...     1
#                  druzy stone pendant with glass beads necklace -...     1
#                  druzy stone ring - black                               1
# 2018-07          you're more important than you realize inspirat...     1
#
# [57280 rows x 1 columns]

# %% [markdown]
# ### Columns where NA's can be filled in from the line above (eg, same order ID)

# %%
# fill_na_above = ['financial_status','paid_at','fulfillment_status','accepts_marketing',
#  'currency','subtotal','shipping','taxes','total','shipping_method','shipping_street',
#  'shipping_address1','shipping_address2','shipping_company','shipping_city','shipping_zip',
#  'shipping_province','shipping_country','payment_method','risk_level','source']

# %%
# df.loc[:,fill_na_above] = df.loc[:,fill_na_above].fillna(method='ffill')
# df.head()
# Out:
#     name financial_status             paid_at fulfillment_status  \
# 0  #4746             paid 2018-07-16 12:31:00        unfulfilled
# 1  #4746             paid 2018-07-16 12:31:00        unfulfilled
# 2  #4746             paid 2018-07-16 12:31:00        unfulfilled
# 3  #4746             paid 2018-07-16 12:31:00        unfulfilled
# 4  #4746             paid 2018-07-16 12:31:00        unfulfilled
#
#   accepts_marketing currency  subtotal  shipping  taxes   total      ...       \
# 0               yes      USD     100.5     13.64    0.0  114.14      ...
# 1               yes      USD     100.5     13.64    0.0  114.14      ...
# 2               yes      USD     100.5     13.64    0.0  114.14      ...
# 3               yes      USD     100.5     13.64    0.0  114.14      ...
# 4               yes      USD     100.5     13.64    0.0  114.14      ...
#
#   risk_level  source                                    lineitem_name.1  \
# 0        Low     web                 Turquoise Crystal Rhinestone Ring
# 1        Low     web                 Turquoise Crystal Rhinestone Ring
# 2        Low     web  Tri Tone Cubic Zirconia Paved Simple Band Ring...
# 3        Low     web             Geometric Tortoise Link Long Necklace
# 4        Low     web  Acetate Skinny Bangle Bracelet With Front Clos...
#
#          color_  unnamed:_39 unnamed:_40  tax_3_name  created_at_yr_mo  \
# 0          GDTQ          NaN         NaN         NaN           2018-07
# 1          GDTQ          NaN         NaN         NaN           2018-07
# 2        Size 8          NaN         NaN         NaN           2018-07
# 3         Brown          NaN         NaN         NaN           2018-07
# 4   White/Brown          NaN         NaN         NaN           2018-07
#
#   created_at_hour created_at_yr
# 0              12          2018
# 1              12          2018
# 2              12          2018
# 3              12          2018
# 4              12          2018
#
# [5 rows x 45 columns]

# %% [markdown]
# ### Check NA's per columns

# %%
df.apply(lambda x: x.isna().sum()/len(df))
# Out:
# unnamed:_0                     0.000000
# name                           0.000000
# financial_status               0.000000
# paid_at                        0.000000
# fulfillment_status             0.000000
# accepts_marketing              0.000000
# currency                       0.000000
# subtotal                       0.000000
# shipping                       0.000000
# taxes                          0.000000
# total                          0.000000
# discount_code                  0.000000
# discount_amount                0.000000
# shipping_method                0.000000
# created_at                     0.000000
# lineitem_quantity              0.000000
# lineitem_name                  0.000000
# lineitem_price                 0.000000
# lineitem_compare_at_price      0.000000
# lineitem_sku                   0.506724
# lineitem_fulfillment_status    0.000000
# shipping_street                0.000000
# shipping_address1              0.000000
# shipping_company               0.000275
# shipping_city                  0.000000
# shipping_zip                   0.000000
# shipping_province              0.000000
# shipping_country               0.000000
# notes                          0.000000
# cancelled                      0.000000
# payment_method                 0.000000
# refunded_amount                0.000000
# vendor                         0.000000
# risk_level                     0.000000
# source                         0.000000
# color                          0.000000
# category                       0.000000
# created_at_yr_mo               0.000000
# created_at_hour                0.000000
# created_at_yr                  0.000000
# dtype: float64

# %% [markdown]
# ### Items with largest purchases in total quantity

# %%
df.groupby("lineitem_name").agg({"name": "count"}).sort_values("name", ascending=0)
# Out:
#                                                     name
# lineitem_name
# urban geometric metal hoop earrings - gold           240
# lightweight urban brass earrings - gold              174
# urban geometric metal hoop earrings - silver         164
# lightweight urban brass earrings - silver            140
# geometric metal hoop earrings - gold                 121
# unisex leather bracelet                              119
# lightweight filigree earrings - gold                  98
# urban geometric metal hoop earrings - rose gold       97
# bohemian magnetic bracelet                            84
# stering silver cubic zirconia studs earrings - ...    84
# multi charm bohemian choker - black                   82
# filigree earrings - gold                              79
# lightweight filigree earrings - rhodium               78
# lace choker                                           76
# stering silver cubic zirconia studs earrings - ...    71
# glass stone metal choker                              69
# lightweight urban brass earrings - rose gold          67
# pearl mini studs earrings - gold                      66
# colorful pompom and thread tassel statement nec...    64
# pearl mini studs earrings - rhodium                   64
# double layered pendant choker                         63
# rhinestone bridal cuff bracelet - gold                61
# bridal hair comb                                      60
# cubic zirconia drop hoop earrings - rhodium           57
# glass stone statement earrings - rhodium              57
# lightweight filigree earrings - matte silver          56
# urban geometric metal hoop earrings                   55
# multi chain lightweight choker necklace set - gold    53
# holiday edition - glass statement necklace - clear    52
# lightweight filigree earrings - matte gold            51
# ...                                                  ...
# magic touch ribbon suede gloves - black                1
# maid of honor hairband                                 1
# magic touch ribbon gloves - ivory                      1
# crystal rhinestone y drop necklace - cr-s              1
# round drop post earrings - sssg                        1
# crystal rhinestone ring - gdlc-7                       1
# round druzy stone stud earrings - black                1
# magic touch poms gloves - gray                         1
# round druzy stud earrings - silver                     1
# crystal stone metal chain y shaped necklace - g...     1
# maid of honor inspirational message bracelet - ...     1
# crystal studs needles - gold                           1
# crystal stone spider brooch                            1
# flower thread tassel earrings - mint                   1
# flower thread tassel earrings - peach                  1
# crystal studs boho choker - gold                       1
# round crystal rings post earrings                      1
# round crystal shiny post earrings                      1
# crystal studs boho choker - black diamond              1
# crystal studs boho choker - black                      1
# crystal stone pumpkin halloween earrings               1
# maid of honor inspirational message bracelet - ...     1
# round cz link - rose gold                              1
# mama bear inspirational message bracelet - gold        1
# make-up remover cleansing tissues with vitamin ...     1
# flower top thread tassel earrings - black              1
# round dream catcher charm and cord necklace            1
# round dream catcher charm and cord necklace - 1+       1
# maid of honor rhinestone headband                      1
# pvc stone thin choker - fuchsia                        1
#
# [26218 rows x 1 columns]

# %% [markdown]
# ### Items with largest purchases from differing orders

# %%
#Items from highest number of differing orders

df.groupby("lineitem_name").agg({"name": pd.Series.nunique}).sort_values("name", ascending=False)
# Out:
#                                                     name
# lineitem_name
# urban geometric metal hoop earrings - gold           108
# lightweight urban brass earrings - gold               99
# lightweight urban brass earrings - silver             89
# urban geometric metal hoop earrings - silver          86
# geometric metal hoop earrings - gold                  74
# lightweight filigree earrings - gold                  66
# urban geometric metal hoop earrings - rose gold       56
# filigree earrings - gold                              56
# lightweight urban brass earrings - rose gold          55
# unisex leather bracelet                               54
# stering silver cubic zirconia studs earrings - ...    53
# bohemian magnetic bracelet                            52
# lightweight filigree earrings - rhodium               51
# all colors restock! suede wrapping choker - black     50
# lace choker                                           48
# rhinestone bridal cuff bracelet - gold                46
# stering silver cubic zirconia studs earrings - ...    44
# boho chic multi layered metal long necklace - s...    41
# urban geometric metal hoop earrings                   40
# lightweight filigree earrings - matte silver          40
# geometric metal hoop earrings - silver                40
# 6pcs multi lace choker set                            40
# all colors restock! suede wrapping choker - brown     40
# glass stone statement earrings - rhodium              38
# holiday edition - glass statement necklace - clear    37
# multi chain lightweight choker necklace set - gold    36
# all colors restock! suede wrapping choker - gray      36
# colorful pompom and thread tassel statement nec...    36
# holiday edition - glass statement necklace - blue     36
# lightweight filigree earrings - matte gold            36
# ...                                                  ...
# organic ornaments y shape bohemian necklace - r...     1
# delicate waterfall necklace                            1
# delicate triple strand thin cuff bracelet - rho...     1
# delicate triple layer beaded short necklace - grey     1
# oriental ball necklace - black                         1
# oriental charm and suede big tassel necklace - ...     1
# denim distressed choker                                1
# organic cut druzy stone pendant necklace - gray        1
# denim inspired daily clutch - dark                     1
# denim inspired daily clutch - light                    1
# omg pendant brass necklace - gold                      1
# omg pendant brass necklace - silver                    1
# diamond cut double teardrop earrings - silver          1
# one day at a time message pendant necklace - si...     1
# opal teardrop glass stone earrings - green             1
# opal teardrop glass stone earrings - white             1
# diamond crystal hook earrings - gdclr                  1
# diamond color blended beads cluster earrings - ...     1
# diagnosal lined double layered flat choker - ro...     1
# diagnosal lined double layered flat choker - rh...     1
# diagnosal lined double layered flat choker - gold      1
# open cage choker                                       1
# denim thin choker - light blue                         1
# open fringe tassel choker - gold                       1
# open hoop and fringe urban earrings                    1
# open hoop earrings - silver                            1
# orange coin purse keychain                             1
# orange flower spring scarf                             1
# organic cut druzy collar long necklace                 1
# premium cubic zirconia rhombus statement earrin...     1
#
# [26218 rows x 1 columns]

# %% [markdown]
# ### Checking words with highest occurence in orders

# %%
#Create a dictionary to see words with highest occurence in orders
item_string = " ".join(df.lineitem_name).split()
item_dict = {}

for i in item_string:
    if i in item_dict.keys():
        item_dict[i] += 1
    else:
        item_dict[i] = 1
        
item_dict

#turning dictionary into dataframe
item_wordcount = pd.DataFrame(pd.Series(item_dict)).rename(columns = {0:"word_count"})
item_wordcount = item_wordcount.sort_values("word_count", ascending=False)
item_wordcount = item_wordcount.drop("-", axis=0)

#plotting results
plot_wordcount = item_wordcount.head(15)
plot_wordcount.sort_values('word_count', ascending=1).plot(kind="barh")

# %% [markdown]
# ### Item Frequency by Year; Plots

# %%
def item_freq(groupdf):
    item_dict = {}
    final_df = pd.DataFrame()
    
    for yr in groupdf.keys():
        
        for i in groupdf[yr]:
            if i in item_dict:
                item_dict[i] += 1
            else:
                item_dict[i] = 1
        
        #turn dictionary into dataframe
        tempdf = pd.DataFrame(pd.Series(item_dict)).rename(columns = {0:"word_count"})
        tempdf["year"] = yr
        final_df = pd.concat([final_df, tempdf], axis=0)
        
    return final_df

# %%
df_grouped = df.groupby("created_at_yr").apply(lambda x: " ".join(x.lineitem_name).split())
item_freq_df = item_freq(df_grouped).sort_values("word_count", ascending=False)
item_freq_df = item_freq_df.drop(["-","and"])
item_freq_df = item_freq_df.reset_index().rename(columns={"index":"word"})

#standardizing word_freq
item_freq_df["word_count_standardized"] = item_freq_df.groupby("year").transform(lambda x: (x-x.mean()) / x.std())
item_freq_df.head()
# Out:
#        word  word_count  year  word_count_standardized
# 0  earrings       31556  2018                32.017114
# 1  necklace       24215  2018                24.533082
# 2  earrings       19775  2017                26.636169
# 3  necklace       17798  2017                23.956280
# 4      gold       15382  2018                15.527980

# %%
#top 15 most mentioned words in sales
top_15_freq = item_freq_df.groupby("year").head(15)
top_15_freq = top_15_freq.sort_values("word_count", ascending=1)

#unpacking groupby element and then plotting 
for year,df_ in top_15_freq.groupby("year"):
    df_.plot("word","word_count_standardized", kind="barh", title=year, legend=None, colormap="tab10")

# %% [markdown]
# ### Check Sales per State

# %%
df.groupby("shipping_province").agg({"name":"count"}).reset_index().sort_values("name", ascending=0).head(15)
# Out:
#    shipping_province   name
# 37                ny  12120
# 12                fl   9517
# 33                nj   9092
# 42                pa   7249
# 45                ri   5919
# 21                ma   4814
# 8                 ct   3828
# 22                md   2809
# 38                oh   2497
# 49                tx   2335
# 24                mi   2191
# 29                nc   1873
# 50                va   1706
# 9                 dc   1582
# 25                mn   1288

# %% [markdown]
# ### Hour of the day with corresponding purchase volume

# %%
df.groupby("created_at_hour").agg({"lineitem_name":"count"}).sort_values("created_at_hour", ascending=1)\
.plot(kind="bar", legend=None)

# %%
import matplotlib.dates as mdates

df.groupby("created_at_yr_mo").agg({"lineitem_name":"count"}).sort_values("created_at_yr_mo", ascending=1)\
.plot(kind="line", legend=None, figsize=(20,10))

# %% [markdown]
# ### Model (Time Series)

# %%
time_sale_df = df.groupby("created_at").agg({"total":"mean"}).reset_index()
time_sale_df = created_at_cols(time_sale_df)
time_sale_df = time_sale_df.groupby("created_at_yr_mo_day").agg({"total":"sum"})

# %%
idx = pd.date_range('10-27-2015', '07-16-2018')

s = time_sale_df.reindex(idx, fill_value=0)
