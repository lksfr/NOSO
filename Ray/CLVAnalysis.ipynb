# %% [markdown]
# # Customer Lifetime Value Analysis
#
# ---------------
#
# ### [Reading pkl and Loading Packages](#intro)
#    - Reading pkl
#    - Loading packages
#
# ### [Data Preparation](#prep)
#    - Creating frequency, recency, age summary
#
# ### [Frequency/Recency Analysis w the BG/NBD model](#bg/nbd)
# - Analyzing customers
# - Predicting probabilities of customer returns
#
# ### [Assessing Model Fit](#fit)
# - Comparing predictions with hold-out model
#
# ### [Customer predictions](#pred)
# - probability of customer buying in period x
# - probability of customer being alive
#
# ### [Estimating average transaction value](#exp)
#
# ### [CLV calculation using DCF](#clv)
#
#
#
# ----------------

# %% [markdown]
# <a id='intro'></a>
# Reading in data & loading packages

# %%
# %matplotlib inline
import scipy.stats as stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_pickle('../Jialan_Zhu/USJH_order_dataset_orderUnit.pkl')

# %%
df.columns
# Out:
# Index(['Name', 'Financial Status', 'Paid at', 'Fulfillment Status',
#        'Accepts Marketing', 'Currency', 'Subtotal', 'Shipping', 'Taxes',
#        'Total', 'Discount Code', 'Discount Amount', 'Shipping Method',
#        'Created at', 'Lineitem fulfillment status', 'Shipping Street',
#        'Shipping Address1', 'Shipping Address2', 'Shipping Company',
#        'Shipping City', 'Shipping Zip', 'Shipping Province',
#        'Shipping Country', 'Notes', 'Note Attributes', 'Cancelled at',
#        'Payment Method', 'Refunded Amount', 'Vendor', 'Tags', 'Risk Level',
#        'Source', 'Color ', 'item_quantity'],
#       dtype='object')

# %%
df['Shipping Company'].u
# Out:
# 0                              US JEWELRY HOUSEW
# 1                              US JEWELRY HOUSEW
# 2                              US JEWELRY HOUSEW
# 3                                La Bella Bijoux
# 4                              US JEWELRY HOUSEW
# 5                                    Kids N more
# 6                                       Lillians
# 7                         Hello Shell Fundrasing
# 8                                        Ragazza
# 9                               Golden Rule, Inc
# 10                        stef's salon & spa llc
# 11                          impressions by tracy
# 12                             The Hidden Closet
# 13                           Somerly Hair Studio
# 14                                  Ruby Blooms
# 15                                   Crimzonrose
# 16                          Eloquii Design, Inc.
# 17                        Statement Accessories
# 18                               The Vanity Room
# 19                                     JKL SALON
# 20                                Direct Jewelry
# 21                                   POSSESSIONS
# 22                                     Nisha spa
# 23                              toni and company
# 24                                       marcell
# 25                                       Bibbege
# 26      APAMO SA DE CV - Kalas Bridal & Boutique
# 27                            Lost City Boutique
# 28                              Golden Rule, Inc
# 29                                        Motifs
#                           ...
# 3716                          Theresa Carrington
# 3717                                  Oraesempre
# 3718                              Stripe & Petal
# 3719                     Serendipity Accessories
# 3720                             Tanya Creations
# 3721                                Dazzle Candy
# 3722                          Hanna's Connection
# 3723                         Millie Lewis Studio
# 3724                  Curvy Gal Consignment, LLC
# 3725                     BGC Retail Consultants
# 3726                                Gennaro, inc
# 3727                                BodyDressers
# 3728                            Aura Accessories
# 3729                              Michele Popper
# 3730                                        Home
# 3731                               Kiddie decor
# 3732                             Yosaira Sanchez
# 3733                             Lana's Loft Inc
# 3734                               Nathalie Bird
# 3735                                ZMC Pharmacy
# 3736                        All Points Beautiful
# 3737                                Mint + Major
# 3738                          SPRINKLE OF KASEYY
# 3739                               People People
# 3740                          Eye Candy Boutique
# 3741                           MallyMae Boutique
# 3742                         Gorgeous Girls Btq.
# 3743                        maura grace boutique
# 3744                             courtney alexis
# 3745                                    t-trendz
# Name: Shipping Company, Length: 3746, dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Financial Status', 'Paid at', 'Fulfillment Status',
#        'Accepts Marketing', 'Currency', 'Subtotal', 'Shipping', 'Taxes',
#        'Total', 'Discount Code', 'Discount Amount', 'Shipping Method',
#        'Created at', 'Lineitem fulfillment status', 'Shipping Street',
#        'Shipping Address1', 'Shipping Address2', 'Shipping Company',
#        'Shipping City', 'Shipping Zip', 'Shipping Province',
#        'Shipping Country', 'Notes', 'Note Attributes', 'Cancelled at',
#        'Payment Method', 'Refunded Amount', 'Vendor', 'Tags', 'Risk Level',
#        'Source', 'Color ', 'item_quantity'],
#       dtype='object')

# %%
#taking shipping street as customer id 
df2 = df[['Created at', 'Shipping Street']]

# %%
df2.head()
# Out:
#            Created at                 Shipping Street
# 0 2015-10-27 16:16:00             1239 Broadway, FLR1
# 1 2015-11-03 16:22:00             1239 Broadway, FLR1
# 2 2015-11-03 16:31:00             1239 Broadway, FLR1
# 3 2015-11-06 16:51:00  2800 Monticello Place, 23- 302
# 4 2015-11-06 18:09:00             1239 Broadway, FLR1

# %% [markdown]
# ### Data Preparation
# <a id='prep'></a>

# %%
from lifetimes.utils import summary_data_from_transaction_data

# %%
summary = summary_data_from_transaction_data(df2, 'Shipping Street', 'Created at', observation_period_end='2018-07-16', freq= 'M')

# %%
summary.head()
# Out:
#                           frequency  recency     T
# Shipping Street
#  105 Arbor Park Drive           3.0     23.0  23.0
#  1428 212 street                0.0      0.0  11.0
# 1 Abbott Road, Unit 68          0.0      0.0  29.0
# 1 David N Meyers Parkway        0.0      0.0  22.0
# 1 Depot Pl                      0.0      0.0  19.0

# %% [markdown]
# **Explanation**:
#
# - *Frequency*: Number of repeat purchases (Total no. of purchases -1)
# - *T*: Age of customer (I specified the time unit to be 'M' for months)
# - *Recency*: Age of customer when they made their last purchase (0 if one-time customer)

# %% [markdown]
# ## Frequency/Recency Analysis w the BG/NBD model
# <a id='bg/nbd'></a>

# %%
from lifetimes import BetaGeoFitter

# %%
bgf = BetaGeoFitter(penalizer_coef=0.0)
bgf.fit(summary['frequency'], summary['recency'], summary['T'])
print(bgf)
# Out:
# <lifetimes.BetaGeoFitter: fitted with 1564 subjects, a: 1.00, alpha: 2.95, b: 4.25, r: 0.29>

# %%
#plotting expected number of future purchases given frequency vs. recency
from lifetimes.plotting import plot_frequency_recency_matrix

plt.figure(figsize=(12,10))
plot_frequency_recency_matrix(bgf)

# %% [markdown]
# **What does this plot show?**
#
# -> If a customer has bought ~18 times from USJH and their and their age at the latest purchase was slightly above 30, they are USJH's best customer
#
# -> Fading tail shows that for customers that have bough around 5 times from USJH and their recency was between 20 and 25, they still might buy again but they also might be dead

# %%
#plotting probability that customer is still alive given frequency vs. recency
from lifetimes.plotting import plot_probability_alive_matrix

plt.figure(figsize=(12,10))
plot_probability_alive_matrix(bgf)

# %%
#ranking customers from best to worst given their probability of buying in the next month
t = 1
summary['predicted_purchases'] = bgf.conditional_expected_number_of_purchases_up_to_time(t, summary['frequency'], summary['recency'], summary['T'])
summary.sort_values(by='predicted_purchases').tail()
# Out:
#                               frequency  recency     T  predicted_purchases
# Shipping Street
# 722 Southwest Westwood Drive        5.0      6.0   6.0             0.509842
# 1924 8th St NW, 115                 4.0      4.0   4.0             0.521295
# 26 Lark Industrial Parkway         10.0     12.0  13.0             0.549611
# 2026 Chestnut Street               10.0     12.0  13.0             0.549611
# 3904 Hwy 22                        12.0     14.0  15.0             0.591664

# %% [markdown]
# -> Customer w address 3904 Hwy 22 has the highest probability of purchasing next month

# %% [markdown]
# ## Assessing model fit
# <a id='fit'></a>

# %%
#comparing our data with artificially simulated data  with our fitted model’s parameters
from lifetimes.plotting import plot_period_transactions

plot_period_transactions(bgf, figsize=(8,6))

# %% [markdown]
# -> model seems to be relevant

# %% [markdown]
# ## Dividing into calibration and holdout data set

# %%
from lifetimes.utils import calibration_and_holdout_data

summary_cal_holdout = calibration_and_holdout_data(df2, 'Shipping Street', 'Created at',
                                        calibration_period_end='2018-01-31',
                                        observation_period_end='2018-07-16', 
                                                   freq='M'
                                                  )   
print(summary_cal_holdout.head())
# Out:
#                           frequency_cal  recency_cal  T_cal  \
# Shipping Street
#  105 Arbor Park Drive               1.0         13.0   17.0
#  1428 212 street                    0.0          0.0    5.0
# 1 Abbott Road, Unit 68              0.0          0.0   23.0
# 1 David N Meyers Parkway            0.0          0.0   16.0
# 1 Depot Pl                          0.0          0.0   13.0
#
#                           frequency_holdout  duration_holdout
# Shipping Street
#  105 Arbor Park Drive                   2.0                 6
#  1428 212 street                        0.0                 6
# 1 Abbott Road, Unit 68                  0.0                 6
# 1 David N Meyers Parkway                0.0                 6
# 1 Depot Pl                              0.0                 6

# %%
from lifetimes.plotting import plot_calibration_purchases_vs_holdout_purchases

bgf.fit(summary_cal_holdout['frequency_cal'], summary_cal_holdout['recency_cal'], summary_cal_holdout['T_cal'])

plot_calibration_purchases_vs_holdout_purchases(bgf, summary_cal_holdout, figsize=(9,7))

# %% [markdown]
# ## Predicting Probability of specific customer buying in X periods
# <a id='intro'></a>

# %%
summary2 = summary
summary2['id'] = summary2.index

# %%
summary2.head()
# Out:
#                           frequency  recency     T  predicted_purchases  \
# Shipping Street
#  105 Arbor Park Drive           3.0     23.0  23.0             0.108200
#  1428 212 street                0.0      0.0  11.0             0.020708
# 1 Abbott Road, Unit 68          0.0      0.0  29.0             0.009085
# 1 David N Meyers Parkway        0.0      0.0  22.0             0.011622
# 1 Depot Pl                      0.0      0.0  19.0             0.013202
#
#                                                 id
# Shipping Street
#  105 Arbor Park Drive         105 Arbor Park Drive
#  1428 212 street                   1428 212 street
# 1 Abbott Road, Unit 68      1 Abbott Road, Unit 68
# 1 David N Meyers Parkway  1 David N Meyers Parkway
# 1 Depot Pl                              1 Depot Pl

# %%
#defining a function that returns the probability of customer x buying in n peridos
def customer_order_prob(periods=1, index=0):

    summary2 = summary
    summary2['id'] = summary2.index
    
    t = index 
    individual = summary2.iloc[periods]
    individual_id = summary2.iloc[index].id
    probability = bgf.predict(t, individual['frequency'], individual['recency'], individual['T'])
    return('The customer residing at ' + individual_id + ' will return over the course of ' + str(periods) + ' periods with a probability of {:.2f}'.format(probability))

# %%
#sample request
customer_order_prob(4, 2)
# Out:
# 'The customer residing at 1 Abbott Road, Unit 68 will return over the course of 4 periods with a probability of 0.03'

# %% [markdown]
# ## Plot predicting probability of customer x being alive

# %%
df2.iloc[2]
# Out:
# Created at         2015-11-03 16:31:00
# Shipping Street    1239 Broadway, FLR1
# Name: 2, dtype: object

# %%
def alive_plotter(address, min_months_alive=5):   
    from lifetimes.plotting import plot_history_alive

  # summary2 = summary
  #  summary2['id'] = summary2.index

  #  individual_id = summary2.iloc[index].id
    
    months_since_birth = 5
    sp_trans = df2.loc[df2['Shipping Street'] == address]
    plt.figure(figsize=(12,10))
    plot_history_alive(bgf, months_since_birth, sp_trans, 'Created at')

# %%
#address id equivalent here - put in any address/id to display graph
alive_plotter('1600 Division Road')

# %% [markdown]
# ## Estimating CLV using Gamma-Gamma Model
# <a id='exp'></a>

# %%
#creating a dataframe including the monetary value of each transaction
summary2 = summary_data_from_transaction_data(df, 'Shipping Street', 'Created at',monetary_value_col='Total', observation_period_end='2018-07-16', freq= 'M')

# %%
summary2.head()
# Out:
#                           frequency  recency     T  monetary_value
# Shipping Street
#  105 Arbor Park Drive           3.0     23.0  23.0      201.683333
#  1428 212 street                0.0      0.0  11.0        0.000000
# 1 Abbott Road, Unit 68          0.0      0.0  29.0        0.000000
# 1 David N Meyers Parkway        0.0      0.0  22.0        0.000000
# 1 Depot Pl                      0.0      0.0  19.0        0.000000

# %%
#filter summary to only include customers that have returned at least once
returning_customers_summary = summary2[summary2['frequency']>0]

returning_customers_summary.head()
# Out:
#                        frequency  recency     T  monetary_value
# Shipping Street
#  105 Arbor Park Drive        3.0     23.0  23.0      201.683333
# 1 Lido Blvd , Apt 1C         4.0      8.0   9.0      384.547500
# 1 Parker Ave, #1208          4.0     16.0  26.0      286.487500
# 1 barnes circle              1.0      5.0  20.0      109.580000
# 1 greenwood court            4.0     12.0  25.0       45.437500

# %%
#Gamma-Gamma model relies on assumption that monetary value and purchase frequency are independent
indep_test = returning_customers_summary[['monetary_value', 'frequency']]

# %%
#correlation
indep_test.corr()
# Out:
#                 monetary_value  frequency
# monetary_value        1.000000   0.066845
# frequency             0.066845   1.000000

# %%
indep_test.plot(x='monetary_value', y='frequency', kind='scatter')

# %%
#fitting model
from lifetimes import GammaGammaFitter

ggf = GammaGammaFitter(penalizer_coef = 0)
ggf.fit(returning_customers_summary['frequency'],
        returning_customers_summary['monetary_value'])
print(ggf)
# Out:
# <lifetimes.GammaGammaFitter: fitted with 560 subjects, p: 2.16, q: 3.18, v: 324.87>

# %% [markdown]
# **Estimating average transaction value**

# %%
CoExAvPr = pd.DataFrame(ggf.conditional_expected_average_profit(
        summary2['frequency'],
        summary2['monetary_value']
    ))

# %%
CoExAvPr.columns = ['conditional_expected_average_profit']

# %%
CoExAvPr.sort_values(by='conditional_expected_average_profit', ascending=False).head(10)
# Out:
#                                        conditional_expected_average_profit
# Shipping Street
# 5650 Greenpointe Drive N, Warehouse C                          2403.029232
# 1239 Broadway                                                  2004.865030
# Seminario 615, Providencia                                     1797.374851
# 99 Farmview DR C                                               1542.083884
# 559 Spring Road                                                1285.901555
# 143 corporate place                                            1274.122657
# 777 NW 72ND AVE, STE 1001                                      1225.111281
# 825 Walnut St.                                                 1193.929008
# 1285 Grandview Avenue                                          1169.956784
# 3772 Main St                                                   1137.712567

# %% [markdown]
# **Calculating total CLV using Discounted Cash Flow Method (DCF)**
# <a id='clv'></a>

# %%
# refit the BG model to the summary_with_money_value dataset
bgf.fit(summary2['frequency'], summary2['recency'], summary2['T'])

clv = pd.DataFrame(ggf.customer_lifetime_value(
    bgf, #the model to use to predict the number of future transactions
    summary2['frequency'],
    summary2['recency'],
    summary2['T'],
    summary2['monetary_value'],
    time=12, # months
    discount_rate=0.01 # monthly discount rate ~ 12.7% annually
))

# %%
clv.sort_values(by='clv', ascending=False).head(10)
# Out:
#                                       clv
# Shipping Street
# 3772 Main St                 29422.242049
# 1908 Haven Bend              29190.172662
# Seminario 615, Providencia   27149.850907
# 10 High ridge Rd             25863.475748
# 825 Walnut St.               21583.124713
# 9810 3rd Ave                 18230.803297
# 425 Dexter Street            17382.726351
# 720 asbury ave               17339.262036
# 1600 Division Road           16930.992844
# 28 jfk blvd                  15348.054454

# %%
#creating a df containing both percentile and our target group assignment
percentile = clv.clv.rank(pct=True)

# %%
clv_percentile = pd.concat([clv, percentile.rename('Percentile')], axis=1)

# %%
clv_percentile.sort_values('Percentile', ascending=False)
# Out:
#                                                clv  Percentile
# Shipping Street
# 3772 Main St                          29422.242049    1.000000
# 1908 Haven Bend                       29190.172662    0.999361
# Seminario 615, Providencia            27149.850907    0.998721
# 10 High ridge Rd                      25863.475748    0.998082
# 825 Walnut St.                        21583.124713    0.997442
# 9810 3rd Ave                          18230.803297    0.996803
# 425 Dexter Street                     17382.726351    0.996164
# 720 asbury ave                        17339.262036    0.995524
# 1600 Division Road                    16930.992844    0.994885
# 28 jfk blvd                           15348.054454    0.994246
# 722 Southwest Westwood Drive          14832.674868    0.993606
# 507 wilmington westchester pike       14143.651175    0.992967
# 1311 Delaware Avenue                  13125.905147    0.992327
# 3010 West Cary Street                 12662.717920    0.991688
# 320 South Quadrille Blvd              12254.848478    0.991049
# 265 N. Lamar Blvd Suite V             12148.765426    0.990409
# 3904 Hwy 22                           11858.839840    0.989770
# 1041 S. Main                          11772.388795    0.989130
# 130 E College Ave                     11750.172161    0.988491
# 1285 Grandview Avenue                 11409.295256    0.987852
# 1924 8th St NW, 115                   11390.898782    0.987212
# 46 Pennsylvania Ave                   10939.616051    0.986573
# Petrune, 126 East State Street        10896.699258    0.985934
# 5 Main Street                         10435.361866    0.985294
# 2026 Chestnut Street                  10434.904619    0.984655
# 30 Commercial Ct                       9163.201967    0.984015
# 360 Narragansett Park Dr               8937.832589    0.983376
# 96 Wharf street                        8911.345465    0.982737
# 1132 S. CHARLES ST.                    8868.458603    0.982097
# 8518 nw 66 street , suite 502          8787.899658    0.981458
# ...                                            ...         ...
# 3721 NE 200TH STREET                    353.597780    0.019182
# 200 S Broad Street, Lobby #4            347.727830    0.018542
# 3 church street                         325.960009    0.017903
# 1281 ELLEN RAY LANE                     324.901397    0.017263
# 2077 West Shore Rd Unit 1               324.588883    0.016624
# 106 Chestnut St #1                      320.644649    0.015985
# 1600 main st                            318.419538    0.015345
# 12216 ocean gateway , 1300              315.377003    0.014706
# 205 NORTH ATLANTIC AVE., 3              312.984039    0.014066
# 2212C Holiday Manor Center              297.301204    0.013427
# 19 W Granada Ave                        289.736631    0.012788
# 750 Via Cafetal                         289.149301    0.012148
# 794 Lexington Ave                       276.295178    0.011509
# 95 SOCKANOSSET CROSS ROAD, SUITE 305    275.849608    0.010870
# 1228 guilford college road, 106         243.652354    0.010230
# 17269 Hampton Blvd                      233.362855    0.009591
# 195 Mowbray Road                        223.610932    0.008951
# 15935 NW 49TH AVENUE, BOX T1247         206.098337    0.008312
# 101 West 143rd Street, Apt. 6           202.899126    0.007673
# 1239 Broadway, FLR1                     201.440666    0.007033
# 504 Vestry Drive                        201.066436    0.006394
# 7701 nw 15th street.suite#LC 670316     176.584516    0.005754
# 4825 butler road , suite 1a             110.860255    0.005115
# 476 Linden Avenue                       104.579861    0.004476
# 706 howe street                         101.122055    0.003836
# 10 WITHERELL ST, APT 505                 80.640285    0.003197
# 14431 Old Bond St                        61.207478    0.002558
# 19 cedar rd                              48.214372    0.001918
# 25 Cumberland Rd                         25.009761    0.001279
# 727 Front street apt 213                 19.754514    0.000639
#
# [1564 rows x 2 columns]

# %%
lis = list(clv_percentile.Percentile)

# %%
lis
# Out:
# [0.887468030690537,
#  0.4114450127877238,
#  0.07736572890025575,
#  0.1649616368286445,
#  0.2311381074168798,
#  0.9680306905370843,
#  0.0879156010230179,
#  0.11445012787723785,
#  0.29987212276214836,
#  0.8759590792838875,
#  0.054987212276214836,
#  0.6799872122762148,
#  0.3414322250639386,
#  0.07225063938618925,
#  0.054987212276214836,
#  0.8900255754475703,
#  0.9980818414322251,
#  0.7739769820971867,
#  0.4114450127877238,
#  0.9757033248081841,
#  0.11892583120204604,
#  0.18446291560102301,
#  0.6799872122762148,
#  0.5466751918158568,
#  0.1010230179028133,
#  0.00319693094629156,
#  0.8567774936061381,
#  0.15089514066496162,
#  0.9443734015345269,
#  0.11445012787723785,
#  0.3705242966751918,
#  0.46451406649616367,
#  0.1649616368286445,
#  0.6799872122762148,
#  0.5466751918158568,
#  0.8177749360613811,
#  0.9731457800511509,
#  0.29987212276214836,
#  0.2477621483375959,
#  0.18446291560102301,
#  0.8727621483375959,
#  0.6592071611253197,
#  0.14002557544757033,
#  0.054987212276214836,
#  0.506074168797954,
#  0.04124040920716113,
#  0.6083759590792839,
#  0.1323529411764706,
#  0.7244245524296675,
#  0.8676470588235294,
#  0.921994884910486,
#  0.5645780051150895,
#  0.20812020460358055,
#  0.5805626598465473,
#  0.1956521739130435,
#  0.5466751918158568,
#  0.06777493606138107,
#  0.4852941176470588,
#  0.506074168797954,
#  0.7244245524296675,
#  0.850383631713555,
#  0.46451406649616367,
#  0.3516624040920716,
#  0.7039641943734015,
#  0.9034526854219949,
#  0.506074168797954,
#  0.9104859335038363,
#  0.329923273657289,
#  0.6397058823529411,
#  0.46451406649616367,
#  0.5466751918158568,
#  0.44884910485933505,
#  0.15089514066496162,
#  0.17391304347826086,
#  0.5805626598465473,
#  0.8938618925831202,
#  0.29987212276214836,
#  0.29987212276214836,
#  0.9661125319693095,
#  0.9961636828644501,
#  0.14002557544757033,
#  0.5620204603580563,
#  0.29987212276214836,
#  0.18446291560102301,
#  0.9622762148337596,
#  0.340153452685422,
#  0.44820971867007675,
#  0.7739769820971867,
#  0.15089514066496162,
#  0.479539641943734,
#  0.6956521739130435,
#  0.8906649616368286,
#  0.6799872122762148,
#  0.46451406649616367,
#  0.5466751918158568,
#  0.4820971867007673,
#  0.620843989769821,
#  0.14002557544757033,
#  0.9437340153452686,
#  0.44565217391304346,
#  0.2477621483375959,
#  0.29987212276214836,
#  0.5805626598465473,
#  0.21994884910485935,
#  0.6397058823529411,
#  0.5466751918158568,
#  0.6397058823529411,
#  0.506074168797954,
#  0.29987212276214836,
#  0.8542199488491049,
#  0.7739769820971867,
#  0.26694373401534527,
#  0.8363171355498721,
#  0.3705242966751918,
#  0.7244245524296675,
#  0.3516624040920716,
#  0.7538363171355499,
#  0.930306905370844,
#  0.18446291560102301,
#  0.5658567774936062,
#  0.9782608695652174,
#  0.8663682864450127,
#  0.12691815856777494,
#  ...]

# %%
new_lis = []

for el in lis:
    
    if el >= 0.75:
        new_lis.append('Gold')
    elif el >= 0.5 and el < 0.75:
        new_lis.append('Silver')
    elif el >= 0.25 and el < 0.5:
        new_lis.append('Bronze')
    elif el >= 0 and el < 0.25:
        new_lis.append('Low Priority')
    else:
        print('Error')

# %%
clv_percentile['ID'] = clv.index

# %%
clv_percentile.reset_index(drop=True, inplace=True)

# %%
target = pd.Series(new_lis)
target = target.astype(str)
target.tail()
# Out:
# 1559    Bronze
# 1560      Gold
# 1561    Bronze
# 1562    Silver
# 1563    Bronze
# dtype: object

# %%
clv_percentile.tail()
# Out:
#               clv  Percentile                                              ID
# 1559   725.765383    0.266944           c/o four star cargo, 7640 n.w 63rd St
# 1560  3015.655210    0.906010  dxb 2534, 182-21 150 Avenue, 182-21 150 avenue
# 1561   748.263605    0.299872             est cerro gordo 64 plaza fabiana 64
# 1562  1377.738092    0.679987                                       po box 35
# 1563   944.294429    0.446931                                      vine house

# %%
final_clv = pd.concat([clv_percentile, target], axis=1)

# %%
final_clv = final_clv[['ID', 'clv', 'Percentile', 0]]
final_clv.columns = ['ID', 'CLV', 'Percentile', 'Target_Group']

# %%
final_clv = final_clv.round(2)

# %%
final_clv.head()
# Out:
#                          ID      CLV  Percentile  Target_Group
# 0      105 Arbor Park Drive  2681.17        0.89          Gold
# 1           1428 212 street   891.84        0.41        Bronze
# 2    1 Abbott Road, Unit 68   540.79        0.08  Low Priority
# 3  1 David N Meyers Parkway   633.23        0.16  Low Priority
# 4                1 Depot Pl   685.18        0.23  Low Priority

# %%
final_clv.to_csv('CLV.csv')

# %%
df = pd.read_csv(
    'https://gist.githubusercontent.com/lksfr/c65d53e66ef45673ce4c8f5ef23e2645/raw/c3dc295facb571959dccc917797158b81d032ac2/CLV.csv',
    index_col=False)

# %%
df = pd.read_csv(
    'https://gist.githubusercontent.com/lksfr/c65d53e66ef45673ce4c8f5ef23e2645/raw/c3dc295facb571959dccc917797158b81d032ac2/CLV.csv',
    index_col=False)

temp = df.drop("Unnamed: 0", axis=1)

temp
# Out:
#                                     ID       CLV  Percentile  Target_Group
# 0                      Piercing Heaven   1757.09        0.67        Silver
# 1                              supreme   1757.09        0.67        Silver
# 2                                    -   1519.04        0.60        Silver
# 3                 1 of a kind boutique    755.69        0.19  Low Priority
# 4     10 Hours of Fashion (Magic Show)    881.44        0.31        Bronze
# 5                    100 Capitol Yards   2115.50        0.74        Silver
# 6                        1800LOVEANDCO   1940.93        0.71        Silver
# 7                                 1986    912.75        0.33        Bronze
# 8                                 1989    983.96        0.37        Bronze
# 9        3 Eleven Salon and Beauty Bar    800.76        0.24  Low Priority
# 10                             33 STAR   1946.35        0.73        Silver
# 11                       4-U (TMK LLC)   1311.91        0.52        Silver
# 12                4th Street Boutique    4557.45        0.90          Gold
# 13                7th Street Surf Shop   1897.27        0.70        Silver
# 14                7th street surf shop  25299.57        0.99          Gold
# 15                                   A    881.44        0.31        Bronze
# 16                   A Beautiful Touch   1612.22        0.63        Silver
# 17                 A Bling Affair, inc    735.25        0.17  Low Priority
# 18                A J Fine and Company  16315.19        0.98          Gold
# 19                    A Little Pizzazz   1612.22        0.63        Silver
# 20                     A Natural Image    800.76        0.24  Low Priority
# 21                  A Taste Of Luxurie   6103.01        0.93          Gold
# 22                       A&B Solutions   1757.09        0.67        Silver
# 23            A's Unique Boutique, LLC    852.52        0.27        Bronze
# 24          A.J. Martin Estate Jewelry   1176.02        0.45        Bronze
# 25                                 AAE    881.44        0.31        Bronze
# 26                         ABW Designs   1940.93        0.71        Silver
# 27                         ABrie Salon   1311.91        0.52        Silver
# 28                  ADRIENE CERMENELLO    912.75        0.33        Bronze
# 29                         AEROPUERTAS   7329.74        0.95          Gold
# ...                                ...       ...         ...           ...
# 1454                             tanya   1069.82        0.40        Bronze
# 1455              tendencia Colombiana   1176.02        0.45        Bronze
# 1456           that little black dress   1315.04        0.54        Silver
# 1457                   the clothesVine   1412.96        0.57        Silver
# 1458              the fashion exchange    594.96        0.05  Low Priority
# 1459                      the gift box   1733.20        0.65        Silver
# 1460               the hanger boutique   1069.82        0.40        Bronze
# 1461            the hills beauty depot    877.56        0.29        Bronze
# 1462                  the pink turtle   20183.15        0.99          Gold
# 1463                   three's company   1421.19        0.57        Silver
# 1464             tickled pink boutique    177.45        0.00  Low Priority
# 1465                  toni and company    582.92        0.03  Low Priority
# 1466    top carrot c/o four star cargo    852.52        0.27        Bronze
# 1467                                tw   1494.24        0.59        Silver
# 1468                veronikas boutique   2608.75        0.83          Gold
# 1469                             vikis   3361.54        0.87          Gold
# 1470           village salon boutique    1757.09        0.67        Silver
# 1471                         vis-a-vis   2533.72        0.82          Gold
# 1472                     weyhill group   1366.73        0.54        Silver
# 1473                    what she wnats   1816.94        0.69        Silver
# 1474                      white Marlie   3806.09        0.88          Gold
# 1475                     white mar lie   1364.87        0.54        Silver
# 1476                       who charlie   1119.91        0.43        Bronze
# 1477                       wildberries   9808.47        0.96          Gold
# 1478                             wiley    800.76        0.24  Low Priority
# 1479                             winks   1176.02        0.45        Bronze
# 1480                               wwl   1612.22        0.63        Silver
# 1481                       you wish it    735.25        0.17  Low Priority
# 1482               your family jeweler    735.25        0.17  Low Priority
# 1483                          zirconia    983.96        0.37        Bronze
#
# [1484 rows x 4 columns]

# %%
df[df["Target_Group"].str.contains("Gold")]
# Out:
#       Unnamed: 0                                        ID       CLV  \
# 12            12                      4th Street Boutique    4557.45
# 14            14                      7th street surf shop  25299.57
# 18            18                      A J Fine and Company  16315.19
# 21            21                        A Taste Of Luxurie   6103.01
# 29            29                               AEROPUERTAS   7329.74
# 30            30                                      AG&G  12251.10
# 35            35                AP/GABRIELA R DE ALDANA/AP   2249.06
# 41            41            ATTN: SATTHRA SAN/MONIQUE HOLT   2185.31
# 42            42                           AXXESORY jUNKEE   2514.94
# 43            43                           About That Girl   4867.07
# 47            47        Abrookin Career & Technical Center   3378.54
# 49            49                                   Accents   4510.78
# 58            58                                   Aenigma   2185.31
# 73            73                      All Points Beautiful   2533.72
# 90            90                           Andrew Charlett   2185.31
# 101          101                        Arcadian Treasures   4189.66
# 107          107                                 AshBmarie   2185.31
# 108          108                    Ashley Austin Boutique   2185.31
# 112          112                      Augusta Mae Boutique   8561.99
# 113          113  Augusta Mae, Boutique & Fine Consignment   2885.57
# 115          115                          Aura Accessories   7851.45
# 116          116                             Ava Frankfurt   3081.32
# 120          120                                 B A Juhls   4463.13
# 125          125                      BAY HIDEAWAY RV PARK   2185.31
# 129          129                   BGC Retail Consultants   23525.29
# 131          131                             BLING Jewelry   3516.31
# 139          139                        Babes & Bombshells   2966.63
# 154          154                        Bedazzled boutique   2220.46
# 155          155                        Bee Hive Gift Shop   4644.54
# 158          158                              Bella Maison   3925.42
# ...          ...                                       ...       ...
# 1363        1363                            fashion closet   2185.31
# 1370        1370                 gary charles & associates   8095.37
# 1372        1372                            glass slipper    2634.67
# 1377        1377                                      home   4194.22
# 1380        1380          hudson valley hospital gift shop   5044.97
# 1384        1384                              ish Boutique   3680.95
# 1391        1391                              jodavi salon   4183.05
# 1394        1394                            just call kara   3754.29
# 1395        1395                            just julez inc   2710.26
# 1399        1399                          la chic boutique   3957.72
# 1401        1401                                   lesters   4017.57
# 1405        1405            lulu clothing and accessories    3223.83
# 1412        1412                      maura grace boutique   2533.72
# 1415        1415                    my sisters jewelry box   3248.49
# 1417        1417                                no company   2185.31
# 1422        1422                          paisley boutique   2185.31
# 1430        1430                             salon deja vu   2878.78
# 1435        1435                            simply Dressed   6230.21
# 1437        1437                                       skm   4779.22
# 1439        1439                           somethingWHITE    2185.31
# 1441        1441                                spa mosaic   5474.45
# 1447        1447                                sunsations  20864.74
# 1451        1451                         t and d design      2473.12
# 1452        1452                                  t-trendz   8300.75
# 1462        1462                          the pink turtle   20183.15
# 1468        1468                        veronikas boutique   2608.75
# 1469        1469                                     vikis   3361.54
# 1471        1471                                 vis-a-vis   2533.72
# 1474        1474                              white Marlie   3806.09
# 1477        1477                               wildberries   9808.47
#
#       Percentile Target_Group
# 12          0.90         Gold
# 14          0.99         Gold
# 18          0.98         Gold
# 21          0.93         Gold
# 29          0.95         Gold
# 30          0.97         Gold
# 35          0.79         Gold
# 41          0.76         Gold
# 42          0.81         Gold
# 43          0.91         Gold
# 47          0.87         Gold
# 49          0.90         Gold
# 58          0.76         Gold
# 73          0.82         Gold
# 90          0.76         Gold
# 101         0.89         Gold
# 107         0.76         Gold
# 108         0.76         Gold
# 112         0.96         Gold
# 113         0.85         Gold
# 115         0.95         Gold
# 116         0.85         Gold
# 120         0.90         Gold
# 125         0.76         Gold
# 129         0.99         Gold
# 131         0.87         Gold
# 139         0.85         Gold
# 154         0.79         Gold
# 155         0.91         Gold
# 158         0.89         Gold
# ...          ...          ...
# 1363        0.76         Gold
# 1370        0.95         Gold
# 1372        0.83         Gold
# 1377        0.89         Gold
# 1380        0.92         Gold
# 1384        0.88         Gold
# 1391        0.89         Gold
# 1394        0.88         Gold
# 1395        0.84         Gold
# 1399        0.89         Gold
# 1401        0.89         Gold
# 1405        0.86         Gold
# 1412        0.82         Gold
# 1415        0.86         Gold
# 1417        0.76         Gold
# 1422        0.76         Gold
# 1430        0.84         Gold
# 1435        0.93         Gold
# 1437        0.91         Gold
# 1439        0.76         Gold
# 1441        0.92         Gold
# 1447        0.99         Gold
# 1451        0.81         Gold
# 1452        0.96         Gold
# 1462        0.99         Gold
# 1468        0.83         Gold
# 1469        0.87         Gold
# 1471        0.82         Gold
# 1474        0.88         Gold
# 1477        0.96         Gold
#
# [378 rows x 5 columns]
